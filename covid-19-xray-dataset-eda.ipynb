# %% [markdown]
# ## Introduction
# The 2019 novel coronavirus (COVID-19) presents several unique features. While the diagnosis is confirmed using polymerase chain reaction (PCR), infected patients with pneumonia may present on chest X-ray and computed tomography (CT) images with a pattern that is only moderately characteristic for the human eye Ng, 2020. Fast diagnostic methods can control and prevent the spread oand assist physicians to better manage patients in high workload conditions. COVID-19’s rate of transmission depends on our capacity to reliably identify infected patients with a low rate of false negatives. In addition, a low rate of false positives is required to avoid further increasing the burden on the healthcare system by unnecessarily exposing patients to quarantine if that is not required. Along with proper infection control, it is evident that timely detection of the disease would enable the implementation of all the supportive care required by patients affected by COVID-19.

# %% [markdown]
# ## Exploratory Analysis

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os 
import pandas as pd

# %% [markdown]
# There is 0 csv file in the current version of the dataset:

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day12.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/ryct.2020200034.fig5-day4.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/ryct.2020200034.fig5-day0.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g09a-Fig9a-day17.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/ryct.2020200034.fig2.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day3.jpg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day2.jpg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/streptococcus-pneumoniae-pneumonia-1.jpg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/ryct.2020200034.fig5-day7.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g07a-Fig7a-day5.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day7.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day0.jpg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/SARS-10.1148rg.242035193-g04mr34g07b-Fig7b-day12.jpeg
# /kaggle/input/xray_dataset_covid19/test/PNEUMONIA/streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day1.jpg
jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0101-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0013-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0103-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0009-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0091-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0070-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0059-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0097-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0015-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0027-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0041-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0084-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0029-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0081-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0110-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0035-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0105-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0021-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0033-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0033-0001-0002.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0012-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0028-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0022-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0030-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0007-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0003-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0107-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0017-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0006-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0043-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0061-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0111-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0102-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0071-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0001-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0031-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0050-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0046-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0011-0001-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0005-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0036-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0016-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0013-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0030-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0023-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0025-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0037-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0099-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0083-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0007-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0039-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0027-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0077-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0089-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0033-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0019-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0011-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0049-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0093-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0029-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0023-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0011-0001-0002.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0063-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0079-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0045-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0086-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0073-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0075-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0087-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0085-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0095-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0033-0001-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0069-0001.jpeg
# /kaggle/input/xray_dataset_covid19/train/NORMAL/IM-0010-0001.jpeg

# %%
train_dir = '/kaggle/input/xray_dataset_covid19/train'
validation_dir ='/kaggle/input/xray_dataset_covid19/test'

# %%
train_normal_dir = os.path.join(train_dir,'NORMAL')
train_pneumonia_dir = os.path.join(train_dir,'PNEUMONIA')
validation_normal_dir = os.path.join(validation_dir,'NORMAL')
validation_pneumonia_dir = os.path.join(validation_dir,'PNEUMONIA')

# %%
train_normal_names = os.listdir(train_normal_dir)
print(train_normal_names[:10])

train_pneumonia_names = os.listdir(train_pneumonia_dir)
print(train_pneumonia_names[:10])
# Out:
# ['IM-0101-0001.jpeg', 'IM-0013-0001.jpeg', 'IM-0103-0001.jpeg', 'IM-0009-0001.jpeg', 'IM-0091-0001.jpeg', 'IM-0070-0001.jpeg', 'IM-0059-0001.jpeg', 'IM-0097-0001.jpeg', 'IM-0015-0001.jpeg', 'NORMAL2-IM-0027-0001.jpeg']
# ['ARDSSevere.png', '1-s2.0-S1684118220300682-main.pdf-002-a1.png', 'jkms-35-e79-g001-l-c.jpg', '2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg', '171CB377-62FF-4B76-906C-F3787A01CB2E.jpeg', 'covid-19-pneumonia-12.jpg', '31BA3780-2323-493F-8AED-62081B9C383B.jpeg', 'covid-19-pneumonia-15-PA.jpg', 'all14238-fig-0001-m-c.jpg', '1-s2.0-S1684118220300682-main.pdf-003-b1.png']

# %%
print('total training normal-rays :', len(os.listdir(train_normal_dir)))
print('total training Pneumonia x-rays:', len(os.listdir(train_pneumonia_dir)))
print('total validation normal-rays :', len(os.listdir(validation_normal_dir)))
print('total validation Pneumonia x-rays:', len(os.listdir(validation_pneumonia_dir)))
# Out:
# total training normal-rays : 74
# total training Pneumonia x-rays: 74
# total validation normal-rays : 20
# total validation Pneumonia x-rays: 20

# %%
import matplotlib.image as mpimg
import seaborn as sns
from PIL import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv2D, MaxPool2D, Flatten
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import cv2 

#filtering warnings
import warnings
warnings.filterwarnings('ignore')

# %%
plt.imshow(cv2.imread("/kaggle/input/xray_dataset_covid19/train/NORMAL/NORMAL2-IM-0013-0001.jpeg"))

# %%
plt.imshow(cv2.imread("/kaggle/input/xray_dataset_covid19/train/PNEUMONIA/acute-respiratory-distress-syndrome-ards-1.jpg"))

# %%
#path to data
path = '/kaggle/input/xray_dataset_covid19/'

#Training Images
train_norm = os.listdir(path + "train/NORMAL")
train_covid = os.listdir(path + "train/PNEUMONIA")

#Testing Images
test_norm = os.listdir(path + "test/NORMAL")
test_covid = os.listdir(path + "test/PNEUMONIA")

# %%
#Dataframe function
def dataframe(filenames, classes):
    return pd.DataFrame({'Filename':filenames, 'Class':[classes]*len(filenames)})

#Forming Train and Test Dataframe
train_norm_df = dataframe(train_norm, 'Normal')
train_covid_df = dataframe(train_covid, 'Covid')

test_norm_df = dataframe(test_norm, 'Normal')
test_covid_df = dataframe(test_covid, 'Covid')

#Concating both classes into single datarame
train_df = pd.concat([train_norm_df, train_covid_df], axis=0)
test_df = pd.concat([test_norm_df, test_covid_df], axis=0)

# %%
#Path maker function
def pathmaker(df_name, df, empty_list):
    for i in df_name.values:
        if i[1] == 'Normal':
            empty_list.append(str(path + df + '/NORMAL/'+i[0]))
        else:
            empty_list.append(str(path + df + '/PNEUMONIA/'+i[0]))


#Empty list to be passed in path maker
train_path = []
test_path = []

#Assigning Path maker
pathmaker(train_df, 'train', train_path)
pathmaker(test_df, 'test', test_path)

train_df['Path'] = train_path
test_df['Path'] = test_path

#Shuffling / Re-arranging rows
train_df = train_df.sample(frac=1).reset_index(drop=True).iloc[:, 1:]
test_df = test_df.sample(frac=1).reset_index(drop=True).iloc[:, 1:]

train_df.head()
# Out:
#     Class                                               Path
# 0   Covid  /kaggle/input/xray_dataset_covid19/train/PNEUM...
# 1   Covid  /kaggle/input/xray_dataset_covid19/train/PNEUM...
# 2   Covid  /kaggle/input/xray_dataset_covid19/train/PNEUM...
# 3  Normal  /kaggle/input/xray_dataset_covid19/train/NORMA...
# 4   Covid  /kaggle/input/xray_dataset_covid19/train/PNEUM...

# %%
# Plotting Normal VS Covid in Grid

sns.set_context('talk')
plt.figure(figsize=(25,12))
plt.subplots_adjust(hspace=0.3)

plt.subplot(2, 2, 1)
plt.imshow(mpimg.imread(train_df[train_df['Class'] == 'Normal']['Path'].values[0]))
plt.title('Normal')

plt.subplot(2, 2, 2)
plt.imshow(mpimg.imread(train_df[train_df['Class'] == 'Normal']['Path'].values[6]))
plt.title('Normal')

plt.subplot(2, 2, 3)
plt.imshow(mpimg.imread(train_df[train_df['Class'] == 'Covid']['Path'].values[28]))
plt.title('COVID-19')

plt.subplot(2, 2, 4)
plt.imshow(mpimg.imread(train_df[train_df['Class'] == 'Covid']['Path'].values[26]))
plt.title('COVID-19')
# Out:
# Text(0.5, 1.0, 'COVID-19')

# %%
#Category count Plot
sns.countplot(train_df['Class'], palette='BrBG')
plt.title('Category Count')
# Out:
# Text(0.5, 1.0, 'Category Count')

# %% [markdown]
# ## Image processing
